# %% [markdown]
# ### This file goes through the dump created by downloadClips and analyzes the quality of transcription by IBM STT

# %%
import json
import numpy as np

# %%
with open('output.json') as data_file:    
    data = json.load(data_file)

# %%
wer_list = []
for clip in data:
    print(clip['movie'] + " " + clip['speaker'] + " " + clip['file'])
    print("Actual: " + clip['text'])
    stt = clip['ibm_output']['results']
    stt_out = ""
    stt_plain_out = ""
    confidence = []
    for frag in stt:
        stt_out = stt_out + "<" + frag['alternatives'][0]['transcript'] + str(frag['alternatives'][0]['confidence']) + ">"
        stt_plain_out = stt_plain_out + frag['alternatives'][0]['transcript']
        confidence.append(frag['alternatives'][0]['confidence'])
    print("Output: " + stt_plain_out)
    #print("<" + stt_out + "> " + str(np.average(confidence)))

    # compute error rate
    wer_val = wer(clip['text'], stt_plain_out)
    wer_rel = 100 * wer_val/len(clip['text'].split())
    wer_list.append(wer_rel)
    
    print('WER = ', str(wer_rel))
              
    print('~~~')
# Out:
# Antitrust (2001) Bob 1.wav
# Actual: See! Who needs computers.
# Output: see these computers
# WER =  50.0
# ~~~
# Antitrust (2001) Lisa 2.wav
# Actual: Guys, we're ok. I've got it under control.
# Output: gosh real got under
# WER =  75.0
# ~~~
# Antitrust (2001) Milo 3.wav
# Actual: Human knowledge belongs to the world!
# Output: human knowledge belongs to the world
# WER =  0.0
# ~~~
# Antitrust (2001) Alice 4.wav
# Actual: No escaping...
# Output:
# WER =  100.0
# ~~~
# Antitrust (2001) Bob 5.wav
# Actual: Do you got something non-geeky I can do?
# Output:
# WER =  100.0
# ~~~
# A Knight's Tale (2001) Chaucer 6.wav
# Actual: Thank you! Thank you I'll be here all week!
# Output: thank you
# WER =  77.7777777778
# ~~~
# A Knight's Tale (2001) Seller 7.wav
# Actual: Cat's meat! Hot wine! Cat's meat! Hot wine!
# Output:
# WER =  100.0
# ~~~
# A Knight's Tale (2001) Wat 8.wav
# Actual: It's called a lance... hullo!
# Output: it's called a long hello
# WER =  40.0
# ~~~
# A Knight's Tale (2001) Jocelyn 9.wav
# Actual: Well that is lovely!
# Output: I'm not exactly
# WER =  100.0
# ~~~
# A Knight's Tale (2001) Crowd 10.wav
# Actual: We will we will rock you!
# Output:
# WER =  100.0
# ~~~
# A Knight's Tale (2001) Wat 11.wav
# Actual: You want to drop behind for a more dramatic victory!
# Output: do you want to drop behind formal domestic victory
# WER =  50.0
# ~~~
# The 13th Warrior (1999) Olga 12.wav
# Actual: You complain much.
# Output: you complain my
# WER =  33.3333333333
# ~~~
# The 13th Warrior (1999) Rethel the Archer 13.wav
# Actual: Don't step in front of me!
# Output: don't step in front of me
# WER =  0.0
# ~~~
# Dudley Do-Right (1999) Narrator 14.wav
# Actual: Meanwhile, back at Snidely's not so secret hideout.
# Output: meanwhile back it's not at least not so secret hideout
# WER =  37.5
# ~~~
# Dudley Do-Right (1999) Whiplash 15.wav
# Actual: Learn from history or repeat it.
# Output: learn from history are
# WER =  50.0
# ~~~
# Dudley Do-Right (1999) Dudley 16.wav
# Actual: I hope it's not hunting season!
# Output: so how do you season
# WER =  83.3333333333
# ~~~
# End of Days (1999) Jericho Cane 17.wav
# Actual: Take it easy. We're the good guys.
# Output: take it easy we're the good guys
# WER =  0.0
# ~~~
# End of Days (1999) Chicago 18.wav
# Actual: Well its official. I'm never sleeping again, ever.
# Output: special I'm never sleeping again ever
# WER =  37.5
# ~~~
# Gladiator (2000) Commodus 19.wav
# Actual: Smile for me now brother.
# Output:
# WER =  100.0
# ~~~
# Gladiator (2000) Commodus 20.wav
# Actual: You simply won't die!
# Output: you simply won't I
# WER =  25.0
# ~~~
# Gladiator (2000) Gladiator 21.wav
# Actual: Go and die with honor!
# Output:
# WER =  100.0
# ~~~
# Gladiator (2000) Maxmius 22.wav
# Actual: The frost, sometimes it makes the blade stick.
# Output: Ross it makes complete stick
# WER =  62.5
# ~~~
# Gladiator (2000) Maximus 23.wav
# Actual: Proximo, are you in danger of becoming a good man?
# Output:
# WER =  100.0
# ~~~
# Gladiator (2000) Lucilla 24.wav
# Actual: Go to them...
# Output:
# WER =  100.0
# ~~~
# Gladiator (2000) Maximus 25.wav
# Actual: At my signal, unleash hell.
# Output: months ago unleash hell
# WER =  60.0
# ~~~
# Gladiator (2000) Commodus 26.wav
# Actual: Am I not merciful!?
# Output:
# WER =  100.0
# ~~~
# Gladiator (2000) Gracchus 27.wav
# Actual: Have you ever embraced someone dying of plague sire?
# Output: I remember someone dying
# WER =  77.7777777778
# ~~~
# Gladiator (2000) Gladiators 28.wav
# Actual: We who are about to die salute you!
# Output:
# WER =  100.0
# ~~~
# Gladiator (2000) Maximus 29.wav
# Actual: The emperor has been slain!
# Output: the emperor as being silly
# WER =  60.0
# ~~~
# Gladiator (2000) Proximo 30.wav
# Actual: That's enough for the moment! His time will come.
# Output: for the moment his time will come
# WER =  22.2222222222
# ~~~
# Gladiator (2000) Juba 31.wav
# Actual: Spaniard, why don't you fight? We all have to fight.
# Output: we'll have to
# WER =  80.0
# ~~~
# Jurassic Park - The Lost World (1997) Ian Malcolm 32.wav
# Actual: Mommy's very angry.
# Output: very angry
# WER =  33.3333333333
# ~~~
# Jurassic Park - The Lost World (1997) Eddie Carr 33.wav
# Actual: Violence and technology, not good bedfellows!
# Output: violence and technology not put bestsellers
# WER =  33.3333333333
# ~~~
# Meet Joe Black (1998) Joe Black 34.wav
# Actual: Hello, I'm Joe Black. It's nice meeting you.
# Output: hello I'm Joe nice
# WER =  50.0
# ~~~
# Meet Joe Black (1998) Joe Black 35.wav
# Actual: Thank you for the delicious cookies.
# Output:
# WER =  100.0
# ~~~
# Meet Joe Black (1998) Drew 36.wav
# Actual: It's just life Quincy. Wake up, smell the thorns.
# Output: it's just life Quincy my god small fun
# WER =  55.5555555556
# ~~~
# Meet Joe Black (1998) Drew 37.wav
# Actual: Mind if I throw up?
# Output: for a while
# WER =  100.0
# ~~~
# Meet Joe Black (1998) Drew 38.wav
# Actual: Who is that guy?!
# Output: who's that guy
# WER =  50.0
# ~~~
# The Patriot (2000) Col. Tavington 39.wav
# Actual: Stupid boy!
# Output:
# WER =  100.0
# ~~~
# The Patriot (2000) British Officer 40.wav
# Actual: One of our captured officers my lord.
# Output: one of our captured offices my old
# WER =  28.5714285714
# ~~~
# The Patriot (2000) Jean Villeneuve 41.wav
# Actual: If I die, I will die well dressed.
# Output: if I die I will die was dressed
# WER =  12.5
# ~~~
# The Patriot (2000) Benjamin Martin 42.wav
# Actual: You have children? .............. *sighs* french.
# Output: French
# WER =  66.6666666667
# ~~~
# The Patriot (2000) Benjamin Martin 43.wav
# Actual: Lord, make me fast and accurate.
# Output: mark my
# WER =  100.0
# ~~~
# Payback (1999) Porter 44.wav
# Actual: Shut up! I cured you!
# Output:
# WER =  100.0
# ~~~
# Payback (1999) Lynn Porter 45.wav
# Actual: You look pretty good for a dead guy.
# Output: it was pretty good
# WER =  75.0
# ~~~
# Payback (1999) Pearl 46.wav
# Actual: Hubba hubba hubba...
# Output:
# WER =  100.0
# ~~~
# Payback (1999) Fairfax 47.wav
# Actual: Man that's just mean! That's mean man!
# Output: yeah that's me that's me man
# WER =  57.1428571429
# ~~~
# Payback (1999) Porter 48.wav
# Actual: They weren't wearing their seat belts.
# Output: they were wearing seatbelts
# WER =  66.6666666667
# ~~~
# Payback (1999) Pearl 49.wav
# Actual: Can't you see I'm working here?
# Output: I'm looking in
# WER =  83.3333333333
# ~~~
# Payback (1999) Val Resnick 50.wav
# Actual: Can't you see I'm working here?!
# Output: did you see I'm working here
# WER =  16.6666666667
# ~~~
# Robin Hood - Prince of Thieves (1991) Azeem 51.wav
# Actual: And they call me barbarian.
# Output: call me Bob
# WER =  60.0
# ~~~
# Robin Hood - Prince of Thieves (1991) Friar Tuck 52.wav
# Actual: He giveth and He taketh away.
# Output: it was a pretty good way
# WER =  100.0
# ~~~
# Robin Hood - Prince of Thieves (1991) Friar Tuck 53.wav
# Actual: I'd rather roast in hell!
# Output: he'd rather roasted now
# WER =  80.0
# ~~~
# Robin Hood - Prince of Thieves (1991) Friar Tuck 54.wav
# Actual: Thank you Lord for teaching me humility.
# Output: thank you lord for teaching you
# WER =  28.5714285714
# ~~~
# Robin Hood - Prince of Thieves (1991) Sheriff of Nottingham 55.wav
# Actual: Join us or die.
# Output: join yes or die
# WER =  25.0
# ~~~
# Robin Hood - Prince of Thieves (1991) Sheriff of Nottingham 56.wav
# Actual: Shut up you twit!
# Output: sure you wait
# WER =  75.0
# ~~~
# Robin Hood - Prince of Thieves (1991) Little John 57.wav
# Actual: Welcome to Sherwood friar!
# Output: sure
# WER =  100.0
# ~~~
# Rules of Engagement (2000) Colonel Childers 58.wav
# Actual: No more multiple choice questions about self-esteem.
# Output: no more multiple choice quiz Steve
# WER =  42.8571428571
# ~~~
# The Cell (2000) Dr. Lee 59.wav
# Actual: The FBI has left the building.
# Output: the FBI has left the building
# WER =  0.0
# ~~~
# The Cell (2000) Catherine Deane 60.wav
# Actual: My world, my rules!
# Output:
# WER =  100.0
# ~~~
# Three Kings (1999) Archie Gates 61.wav
# Actual: God bless America! And God bless a free Iraq!
# Output:
# WER =  100.0
# ~~~
# Three Kings (1999) Conrad Vig 62.wav
# Actual: We three kings be stealing the gold.
# Output: we three kings these delaying the go
# WER =  42.8571428571
# ~~~
# Remember the Titans (2000) Guy 63.wav
# Actual: What did they do up there? Brainwash them?
# Output: they do it to rain wash
# WER =  75.0
# ~~~
# Remember the Titans (2000) Nicky Boone 64.wav
# Actual: Momma? Are all white girls that crazy?
# Output: my gosh
# WER =  100.0
# ~~~
# Tremors (1990) Valentine McKee 65.wav
# Actual: Who died and made you Einstein?!
# Output: god made you on does
# WER =  83.3333333333
# ~~~
# Tremors (1990) Valentine McKee 66.wav
# Actual: I can't believe we said no to free beer!
# Output:
# WER =  100.0
# ~~~
# Tremors (1990) Valentine McKee 67.wav
# Actual: Well, it just suddenly hit me. You know, stampede.
# Output: well it just suddenly hit me you know stampede
# WER =  0.0
# ~~~
# Tremors (1990) Valentine McKee 68.wav
# Actual: Could you shut up!
# Output: could you
# WER =  50.0
# ~~~
# Tremors (1990) Rhonda LeBeck 69.wav
# Actual: Did you notice anything weird a minute ago?
# Output: did you notice anything weird a minute ago
# WER =  0.0
# ~~~
# Tremors (1990) Valentine McKee 70.wav
# Actual: I know! I know! I'm working up to it!
# Output: I know I know working up to it
# WER =  11.1111111111
# ~~~
# U-571 (2000) Lt. Andrew Tyler 71.wav
# Actual: Let's abandon ship.
# Output:
# WER =  100.0
# ~~~
# U-571 (2000) Lt. Andrew Tyler 72.wav
# Actual: His body is gonna to save our lives.
# Output: his body is going to save our lives
# WER =  12.5
# ~~~
# U-571 (2000) Seaman Bill Wentz 73.wav
# Actual: I am U-571. Destroy me!
# Output:
# WER =  100.0
# ~~~
# U-571 (2000) Chief Henry Klough 74.wav
# Actual: Dive! Dive! Dive!
# Output:
# WER =  100.0
# ~~~
# U-571 (2000) Lt. Andrew Tyler 75.wav
# Actual: Fire!! Tank fire right now or we die!
# Output:
# WER =  100.0
# ~~~
# U-571 (2000) Captain Dahlgren 76.wav
# Actual: Relax gentlemen. She's old, but she'll hold.
# Output: relax these old she'll
# WER =  57.1428571429
# ~~~
# U.S. Marshals (1998) Marshal Sam Gerard 77.wav
# Actual: Drop the gun pal!
# Output:
# WER =  100.0
# ~~~
# U.S. Marshals (1998) Marshal Sam Gerard 78.wav
# Actual: Ok Michael, regular or extra crispy?
# Output: okay Michael regular or extra crispy
# WER =  16.6666666667
# ~~~
# U.S. Marshals (1998) Marshal Sam Gerard 79.wav
# Actual: That is not a ball point pen.
# Output: that is not going to
# WER =  57.1428571429
# ~~~
# Zulu (1964) Lieutenant Bromhead 80.wav
# Actual: What are you waiting for? Come on! Come on!
# Output: what are you waiting for all come on come on
# WER =  11.1111111111
# ~~~
# Zulu (1964) Colour-Sergeant Bourne 81.wav
# Actual: Alright, nobody told you to stop working.
# Output: I've never told to stop working
# WER =  42.8571428571
# ~~~
# Jurassic Park 3 (2001) Dr. Alan Grant 82.wav
# Actual: Reverse Darwinism. Survival of the most idiotic.
# Output: most
# WER =  85.7142857143
# ~~~
# Jurassic Park 3 (2001) Dr. Alan Grant 83.wav
# Actual: You cannot land on this island!
# Output:
# WER =  100.0
# ~~~
# Jurassic Park 3 (2001) Dr. Alan Grant 84.wav
# Actual: We haven't landed yet.
# Output: we have landed
# WER =  50.0
# ~~~
# Jurassic Park 3 (2001) Dr. Alan Grant 85.wav
# Actual: Nobody move a muscle!
# Output: nobody %HESITATION
# WER =  75.0
# ~~~
# Jurassic Park 3 (2001) Mr. Udesky 86.wav
# Actual: If we split up, I'm going with you guys.
# Output: split up he is a
# WER =  77.7777777778
# ~~~
# Braveheart (1995) William Wallace 87.wav
# Actual: Are you ready for a war!
# Output:
# WER =  100.0
# ~~~
# Braveheart (1995) Scotsman 88.wav
# Actual: Arm yourselves!
# Output:
# WER =  100.0
# ~~~
# Braveheart (1995) Hamish 89.wav
# Actual: Well, we didn't get dressed up for nothing.
# Output: well didn't get dressed up for nothing
# WER =  12.5
# ~~~
# Braveheart (1995) William Wallace 90.wav
# Actual: Every man dies, not every man really lives.
# Output:
# WER =  100.0
# ~~~
# Braveheart (1995) Hamish 91.wav
# Actual: I could crush you..... like a worm!
# Output: of course you like a lot of
# WER =  71.4285714286
# ~~~
# Braveheart (1995) King Edward 92.wav
# Actual: Irish...
# Output: I
# WER =  100.0
# ~~~
# Muppet Treasure Island (1996) Bad Polly Lobster 93.wav
# Actual: Cowabunga!
# Output:
# WER =  100.0
# ~~~
# Muppet Treasure Island (1996) Squire Trelawney (Fozzie Bear) 94.wav
# Actual: This is not fun!!
# Output:
# WER =  100.0
# ~~~
# Robin Hood - Men in Tights (1993) Ahchoo 95.wav
# Actual: White men can't jump.
# Output: and so
# WER =  100.0
# ~~~
# Robin Hood - Men in Tights (1993) Prince John 96.wav
# Actual: Check please. Table one.
# Output:
# WER =  100.0
# ~~~
# Robin Hood - Men in Tights (1993) Prince John 97.wav
# Actual: Funny! Very amusing!
# Output: remember
# WER =  100.0
# ~~~
# Goldeneye (1995) James Bond 98.wav
# Actual: No more foreplay.
# Output:
# WER =  100.0
# ~~~
# Goldeneye (1995) Boris Grishenko 99.wav
# Actual: Yes! I am invincible!
# Output:
# WER =  100.0
# ~~~
# Goldeneye (1995) James Bond 100.wav
# Actual: Bond, James Bond.
# Output:
# WER =  100.0
# ~~~
# Goldeneye (1995) Q 101.wav
# Actual: Now pay attention 007.
# Output:
# WER =  100.0
# ~~~
# Goldeneye (1995) James Bond 102.wav
# Actual: She always did enjoy a good squeeze.
# Output: show students
# WER =  100.0
# ~~~
# Goldeneye (1995) James Bond 103.wav
# Actual: That's one trick I never learned.
# Output:
# WER =  100.0
# ~~~
# Goldeneye (1995) James Bond 104.wav
# Actual: Vodka Martini. Shaken, not stirred.
# Output: but come on shaken not stirred
# WER =  60.0
# ~~~
# You've Got Mail (1998) Kathleen Kelly 105.wav
# Actual: Don't you just love New York in the fall?
# Output:
# WER =  100.0
# ~~~
# You've Got Mail (1998) Patricia Eden 106.wav
# Actual: Where are my tic-tacs?
# Output: we're my tax
# WER =  75.0
# ~~~
# Men in Black (1997) Agent K 107.wav
# Actual: Zed, we have a bug.
# Output: said we have a bug
# WER =  20.0
# ~~~
# Men in Black (1997) Agent J 108.wav
# Actual: I make this look good!
# Output: I make this look good
# WER =  0.0
# ~~~
# Men in Black (1997) Agent K 109.wav
# Actual: We are the men in black.
# Output:
# WER =  100.0
# ~~~
# Men in Black (1997) Agent J 110.wav
# Actual: Sorry y'all! It was an accident... Sorry.
# Output: are ya at sorry
# WER =  85.7142857143
# ~~~
# Men in Black (1997) Agent J 111.wav
# Actual: I'm telling you that man does not look stable.
# Output:
# WER =  100.0
# ~~~
# Men in Black (1997) Jack Jeebs 112.wav
# Actual: Do you have any idea how much that stings?!
# Output:
# WER =  100.0
# ~~~
# Men in Black (1997) Agent K 113.wav
# Actual: You are no longer part of the system.
# Output:
# WER =  100.0
# ~~~
# First Knight (1995) Lancelot 114.wav
# Actual: I knew I could do it so I did it.
# Output: I knew I could do it so I did it
# WER =  0.0
# ~~~
# GroundHog Day (1993) Phil Connors 115.wav
# Actual: Don't drive angry! Don't drive angry!
# Output: I agree
# WER =  100.0
# ~~~
# GroundHog Day (1993) Ned Ryerson 116.wav
# Actual: Watch out for that first step! Its a doozey!
# Output: watch out for the first step in and do you see
# WER =  66.6666666667
# ~~~
# GroundHog Day (1993) Phil Connors 117.wav
# Actual: Moron, your bus is leaving.
# Output: your boss is leading
# WER =  60.0
# ~~~
# GroundHog Day (1993) Phil Connors 118.wav
# Actual: I'm not gonna live by their rules anymore!
# Output:
# WER =  100.0
# ~~~
# GroundHog Day (1993) Phil Connors 119.wav
# Actual: Gosh you're an upbeat lady!
# Output: gosh you're an upbeat lady
# WER =  0.0
# ~~~
# Evolution (2001) Harry Block 120.wav
# Actual: Ira! Don't you ever tell anyone where I've been!
# Output:
# WER =  100.0
# ~~~
# Evolution (2001) Governor Lewis 121.wav
# Actual: Keeping my chair warm for me are ya?
# Output: much your warm for me
# WER =  62.5
# ~~~
# Evolution (2001) Harry Block 122.wav
# Actual: I'm picking up a heavy creepy vibe here.
# Output:
# WER =  100.0
# ~~~
# Evolution (2001) Harry Block 123.wav
# Actual: Anyone have a can of raid?
# Output: I got a kind of raised
# WER =  66.6666666667
# ~~~
# Evolution (2001) Harry Block 124.wav
# Actual: Come on, admit it. You're glad to see us.
# Output: come on admit it glad to see you
# WER =  22.2222222222
# ~~~
# Evolution (2001) Harry Block 125.wav
# Actual: Now that's really peculiar.
# Output: now that we can
# WER =  75.0
# ~~~
# Much Ado About Nothing (1993) Benedick 126.wav
# Actual: And this is my conclusion.
# Output: this is my conclusion
# WER =  20.0
# ~~~
# Much Ado About Nothing (1993) Benedick 127.wav
# Actual: Ha! The prince, and monsieur love.
# Output: the prince and miss you do
# WER =  66.6666666667
# ~~~
# Much Ado About Nothing (1993) Benedick 128.wav
# Actual: Serve God, love me, and mend.
# Output: so that's cool no
# WER =  100.0
# ~~~
# Much Ado About Nothing (1993) Don Pedro 129.wav
# Actual: This learned constable is too cunning to be understood.
# Output: this learn it constable is too cunning to be understood
# WER =  22.2222222222
# ~~~
# Much Ado About Nothing (1993) Benedick 130.wav
# Actual: Love me?! Why?!
# Output: %HESITATION
# WER =  100.0
# ~~~
# Red Planet (2000) Kate Bowman 131.wav
# Actual: I learned how to drink in the Navy boys.
# Output: another drink
# WER =  88.8888888889
# ~~~
# Red Planet (2000) Robby Gallagher 132.wav
# Actual: God works in mysterious ways.
# Output:
# WER =  100.0
# ~~~
# Shrek (2001) Princess 133.wav
# Actual: Man that was annoying!
# Output: man that was annoying
# WER =  0.0
# ~~~
# Shrek (2001) Wooden Puppet 134.wav
# Actual: I'm not a puppet! I'm a real boy!
# Output: not a %HESITATION
# WER =  75.0
# ~~~
# Shrek (2001) Shrek 135.wav
# Actual: Why are you following me?!
# Output: why are you following me
# WER =  0.0
# ~~~
# Shrek (2001) Donkey 136.wav
# Actual: Wow! Only a true friend would be that truly honest.
# Output: only a true friend would be that cruelly yes
# WER =  30.0
# ~~~
# Shrek (2001) Shrek 137.wav
# Actual: Sure it's big enough... but look at the location.
# Output: you know hello
# WER =  100.0
# ~~~
# Shrek (2001) Donkey 138.wav
# Actual: Oh pick me! Oh I know! I know! Me! Me!
# Output: okay I know
# WER =  80.0
# ~~~
# Shrek (2001) Shrek 139.wav
# Actual: Thank you very much! I'm here till Thursday!
# Output: I need to learn to
# WER =  100.0
# ~~~
# Black Adder Goes Forth (1989) Captain Kevin Darling 140.wav
# Actual: Good luck against those elephants.
# Output: good luck against us
# WER =  40.0
# ~~~
# Lord of the Rings - The Two Towers (2002) Gimli 141.wav
# Actual: You'll find more cheer in a graveyard.
# Output: more the rain
# WER =  85.7142857143
# ~~~
# Lord of the Rings - The Two Towers (2002) Saruman 142.wav
# Actual: There will be no dawn for men!
# Output:
# WER =  100.0
# ~~~
# Lord of the Rings - The Two Towers (2002) Pippen 143.wav
# Actual: Don't talk to it Merry! Don't encourage it!
# Output:
# WER =  100.0
# ~~~
# Lord of the Rings - The Two Towers (2002) Uruk-Hai 144.wav
# Actual: Looks like meat is back on the menu boys!
# Output:
# WER =  100.0
# ~~~
# Lord of the Rings - The Two Towers (2002) Boromir 145.wav
# Actual: Remember today little brother! Today life is good.
# Output: remember brother
# WER =  75.0
# ~~~
# Lord of the Rings - The Two Towers (2002) Legolas 146.wav
# Actual: The white wizard approaches.
# Output: why would approach
# WER =  100.0
# ~~~
# Lord of the Rings - Fellowship of the Ring (2001) Aragorn 147.wav
# Actual: You draw far too much attention to yourself Mr. Underhill.
# Output: five to
# WER =  90.0
# ~~~
# Lord of the Rings - Fellowship of the Ring (2001) Arwen 148.wav
# Actual: If you want him, come and claim him!
# Output:
# WER =  100.0
# ~~~
# Lord of the Rings - Fellowship of the Ring (2001) Gandalf 149.wav
# Actual: I suppose you think that was terribly clever.
# Output:
# WER =  100.0
# ~~~
# Lord of the Rings - Fellowship of the Ring (2001) Gandalf 150.wav
# Actual: They are coming...
# Output:
# WER =  100.0
# ~~~
# Lord of the Rings - Fellowship of the Ring (2001) Gandalf 151.wav
# Actual: The ring must be destroyed.
# Output: strong
# WER =  100.0
# ~~~
# Lord of the Rings - Fellowship of the Ring (2001) Frodo 152.wav
# Actual: Get off the road!
# Output: do you
# WER =  100.0
# ~~~
# Lord of the Rings - Fellowship of the Ring (2001) Gandalf 153.wav
# Actual: You shall not pass!
# Output:
# WER =  100.0
# ~~~
# Lord of the Rings - Fellowship of the Ring (2001) Saruman 154.wav
# Actual: We have work to do.
# Output: well to tell
# WER =  80.0
# ~~~
# My Favorite Brunette (1947) Ronnie Jackson 155.wav
# Actual: Easy cuddles! One move and you're a dead midget!
# Output: do you think one when you're right that makes
# WER =  88.8888888889
# ~~~
# My Favorite Brunette (1947) Willie 156.wav
# Actual: You gotta be neat ya know!
# Output: you got to be neat to go
# WER =  66.6666666667
# ~~~
# My Favorite Brunette (1947) Ronnie Jackson 157.wav
# Actual: You can open the mailman later.
# Output: you can open the mail man later
# WER =  33.3333333333
# ~~~
# My Favorite Brunette (1947) Ronnie Jackson 158.wav
# Actual: Oh oh, her's schizo's about to frania.
# Output: our risk it so is about to Frannie
# WER =  85.7142857143
# ~~~
# My Favorite Brunette (1947) Ronnie Jackson 159.wav
# Actual: Everything you touch turns to Rigor mortis.
# Output: touch turns the regular ones
# WER =  71.4285714286
# ~~~
# Jonah - A VeggieTales Movie (2002) Khalil 160.wav
# Actual: I'm coming traveling buddy!
# Output:
# WER =  100.0
# ~~~
# Jonah - A VeggieTales Movie (2002) Khalil 161.wav
# Actual: Crime fighting runs very deep in my family.
# Output:
# WER =  100.0
# ~~~
# Jonah - A VeggieTales Movie (2002) Pa Grape 162.wav
# Actual: It seems not doing anything, didn't pay very well.
# Output: it seems not doing anything didn't pay very well
# WER =  0.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Data 163.wav
# Actual: I'm ready to irradiate your existing brain cells.
# Output: I'm ready to a radiator existing brain cells
# WER =  25.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Data 164.wav
# Actual: Are you able to cease thinking on command?
# Output: you were able to seize thinking on command
# WER =  37.5
# ~~~
# Star Trek - The Next Generation (1987-1994) Q 165.wav
# Actual: These aren't my colors!
# Output:
# WER =  100.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Worf 166.wav
# Actual: Klingon's do not procrastinate. It is a tactical delay.
# Output: click on he lay
# WER =  100.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Q 167.wav
# Actual: What, is there an echo in here?!
# Output:
# WER =  100.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Captain Jean-Luc Picard 168.wav
# Actual: Get off my bridge!
# Output: my bridge
# WER =  50.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Lt. Worf 169.wav
# Actual: We are being hailed sir.
# Output: we're being Sir
# WER =  60.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Captain Jean-Luc Picard 170.wav
# Actual: Would you mind identifying what you are?
# Output: do you mind identifying what you are
# WER =  14.2857142857
# ~~~
# Star Trek - The Next Generation (1987-1994) Q 171.wav
# Actual: I'm immortal again! Omnipotent again!
# Output:
# WER =  100.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Worf 172.wav
# Actual: You see! You see! They are insane!
# Output: are you
# WER =  85.7142857143
# ~~~
# Star Trek - The Next Generation (1987-1994) Worf 173.wav
# Actual: Sir, I protest! I am not a merry man!
# Output: Sir I protest I am not a merry men
# WER =  11.1111111111
# ~~~
# Star Trek - The Next Generation (1987-1994) Lt. Worf 174.wav
# Actual: Nice legs, for a human.
# Output: by slicks before you
# WER =  100.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Captain Jean-Luc Picard 175.wav
# Actual: Proceed.
# Output: save
# WER =  100.0
# ~~~
# Star Trek - The Next Generation (1987-1994) Data 176.wav
# Actual: I am not your puppet anymore.
# Output: I am not your puppet name
# WER =  16.6666666667
# ~~~
# Star Trek - The Next Generation (1987-1994) Captain Jean-Luc Picard 177.wav
# Actual: Red alert! All crew to battle stations!
# Output:
# WER =  100.0
# ~~~
# The X Files (1993-2002) Dana Scully 178.wav
# Actual: Not everything is about you, Mulder.
# Output: not everything is about you her
# WER =  16.6666666667
# ~~~
# The X Files (1993-2002) Fox Mulder 179.wav
# Actual: Sorry, nobody down here but the FBI's most unwanted.
# Output:
# WER =  100.0
# ~~~
# The X Files (1993-2002) Fox Mulder 180.wav
# Actual: I get tired of losing my gun.
# Output: my gun
# WER =  71.4285714286
# ~~~
# The X Files (1993-2002) Fox Mulder 181.wav
# Actual: He didn't even touch his jello.
# Output: John
# WER =  100.0
# ~~~
# 2001 - A Space Odyssey (1968) HAL 9000 182.wav
# Actual: This conversation can serve no purpose anymore. Goodbye.
# Output: this sanction concert because I mean
# WER =  87.5
# ~~~
# 2001 - A Space Odyssey (1968) HAL 9000 183.wav
# Actual: There is a message for you.
# Output: I was a mess
# WER =  83.3333333333
# ~~~
# 2001 - A Space Odyssey (1968) HAL 9000 184.wav
# Actual: It can only be attributable to human error.
# Output:
# WER =  100.0
# ~~~
# 2001 - A Space Odyssey (1968) HAL 9000 185.wav
# Actual: I'm sorry. I'm afraid I can't do that.
# Output:
# WER =  100.0
# ~~~
# 2001 - A Space Odyssey (1968) HAL 9000 186.wav
# Actual: Just what do you think you're doing?
# Output: yes
# WER =  100.0
# ~~~
# 2001 - A Space Odyssey (1968) HAL 9000 187.wav
# Actual: Take a stress pill and think things over.
# Output:
# WER =  100.0
# ~~~
# The X Files Movie - Fight the Future (1998) Well-Manicured Man 188.wav
# Actual: Trust no one Mister Mulder.
# Output:
# WER =  100.0
# ~~~
# Aliens (1986) Burke 189.wav
# Actual: That could've been better.
# Output: I could've
# WER =  75.0
# ~~~
# Aliens (1986) Hicks 190.wav
# Actual: Now all we need is a deck of cards.
# Output: thank god
# WER =  100.0
# ~~~
# Aliens (1986) Hudson 191.wav
# Actual: You're dog meat pal!
# Output: told me
# WER =  100.0
# ~~~
# Aliens (1986) Hudson 192.wav
# Actual: We're on an express elevator to hell, going down!
# Output:
# WER =  100.0
# ~~~
# Aliens (1986) Hudson 193.wav
# Actual: That wasn't funny man!
# Output: email
# WER =  100.0
# ~~~
# Aliens (1986) Hudson 194.wav
# Actual: That's it man. Game over man! Game over!
# Output: the man game over cable over
# WER =  50.0
# ~~~
# Aliens (1986) Ellen Ripley 195.wav
# Actual: Get away from her, you *****!
# Output:
# WER =  100.0
# ~~~
# Aliens (1986) Ellen Ripley 196.wav
# Actual: Did IQs just drop sharply while I was away?!
# Output: the dark use just drop sharply while I was away
# WER =  33.3333333333
# ~~~
# Aliens (1986) Frost 197.wav
# Actual: I hate this job.
# Output:
# WER =  100.0
# ~~~
# Aliens (1986) Hicks 198.wav
# Actual: Looks like love at first sight to me.
# Output: right
# WER =  100.0
# ~~~
# Aliens (1986) Sarge 199.wav
# Actual: Alright, I want combat seating, you know your places.
# Output: I don't want to comment you know you places
# WER =  55.5555555556
# ~~~
# Aliens (1986) Newt 200.wav
# Actual: You don't have to be sorry. It wasn't your fault.
# Output: everything is fine
# WER =  100.0
# ~~~
# Aliens (1986) Sarge 201.wav
# Actual: Nobody touch nothing!
# Output:
# WER =  100.0
# ~~~
# Star Trek Generations (1994) Dr. Tolian Soran 202.wav
# Actual: Haven't you got anything better to do?
# Output: haven't you got anything better to do
# WER =  0.0
# ~~~
# Star Trek Generations (1994) Scotty 203.wav
# Actual: Captain, is there something wrong with your chair?
# Output:
# WER =  100.0
# ~~~
# Star Trek Generations (1994) Worf 204.wav
# Actual: Klingon vessel decloaking directly ahead sir!
# Output:
# WER =  100.0
# ~~~
# Star Trek Generations (1994) Laforge 205.wav
# Actual: Can we just get down to it please?
# Output:
# WER =  100.0
# ~~~
# Star Trek Generations (1994) Lursa 206.wav
# Actual: Human females are so repulsive!
# Output:
# WER =  100.0
# ~~~
# Star Trek Generations (1994) Data 207.wav
# Actual: Oohhhh yess! I hate this! It is revolting!
# Output: %HESITATION yes I hate this is we're both
# WER =  62.5
# ~~~
# Star Trek Generations (1994) Data 208.wav
# Actual: I just love scanning for lifeforms.
# Output:
# WER =  100.0
# ~~~
# Star Trek Generations (1994) Riker 209.wav
# Actual: Computer, remove the plank!
# Output: my name
# WER =  100.0
# ~~~
# Star Trek Generations (1994) Dr. Tolian Soran 210.wav
# Actual: It's like a predator, it's stalking you.
# Output: so I
# WER =  100.0
# ~~~
# Star Trek Generations (1994) Data 211.wav
# Actual: Yes!
# Output:
# WER =  100.0
# ~~~
# Signs (2002) Graham Hess 212.wav
# Actual: Is it possible that there are no coincidences?
# Output: possible there are no coincidences
# WER =  37.5
# ~~~
# Signs (2002) Bo Hess 213.wav
# Actual: It's contaminated.
# Output: you can
# WER =  100.0
# ~~~
# Signs (2002) Graham Hess 214.wav
# Actual: It's happening.
# Output:
# WER =  100.0
# ~~~
# Signs (2002) Bo Hess 215.wav
# Actual: Why can't they get girlfriends?
# Output: you can't go from
# WER =  80.0
# ~~~
# Signs (2002) Merrill Hess 216.wav
# Actual: This is exactly what the nerds want.
# Output: exactly what the nurse one
# WER =  57.1428571429
# ~~~
# Training Day (2001) Det. Alonzo Harris 217.wav
# Actual: All that jelly and no toast.
# Output: all last year
# WER =  83.3333333333
# ~~~
# Muppets from Space (1999) Dr Teeth 218.wav
# Actual: Shalom!
# Output:
# WER =  100.0
# ~~~
# My Big Fat Greek Wedding (2002) Gus 219.wav
# Actual: You better get married soon. Your starting to look old.
# Output: you better get money so you use stone into %HESITATION
# WER =  70.0
# ~~~
# The Matrix Reloaded (2003) Persephone 220.wav
# Actual: Cause and effect my love.
# Output: cause and effect to my knowledge
# WER =  40.0
# ~~~
# The Matrix Reloaded (2003) The Architect 221.wav
# Actual: Denial is the most predictable of all human responses.
# Output: denial is the most predictable responses
# WER =  33.3333333333
# ~~~
# The Matrix Reloaded (2003) Trinity 222.wav
# Actual: That's a nice trick.
# Output:
# WER =  100.0
# ~~~
# The Matrix Reloaded (2003) Agent Smith 223.wav
# Actual: Yes that's it, it will be over soon.
# Output: deal
# WER =  100.0
# ~~~
# The Matrix Reloaded (2003) Trinity 224.wav
# Actual: Why don't you sample this instead!
# Output: what is your simple this instead
# WER =  66.6666666667
# ~~~
# The Matrix Reloaded (2003) Merovingian 225.wav
# Actual: Ok, you have some skill.
# Output: okay you have some skin
# WER =  40.0
# ~~~
# Lord of the Rings - The Return of the King (2003) Aragorn 226.wav
# Actual: My friends, you bow to no one.
# Output: %HESITATION
# WER =  100.0
# ~~~
# Lord of the Rings - The Return of the King (2003) Aragorn 227.wav
# Actual: I do not fear death!
# Output:
# WER =  100.0
# ~~~
# The Adventures of Robin Hood (1938) Robin Hood 228.wav
# Actual: Better look before you shoot next time little man.
# Output: look before you shoot next time the man
# WER =  22.2222222222
# ~~~
# The Adventures of Robin Hood (1938) Sheriff 229.wav
# Actual: Such impudence your highness! If I could only reach him!
# Output: so I just
# WER =  90.0
# ~~~
# The Adventures of Robin Hood (1938) Robin Hood 230.wav
# Actual: Welcome to Sherwood my lady.
# Output: showed my lady
# WER =  60.0
# ~~~
# Black Adder II (1986) Lord Percy 231.wav
# Actual: I like you young Bob. You've got balls!
# Output: I like your young both you go below
# WER =  62.5
# ~~~
# The Ring (2002) Noah 232.wav
# Actual: Call me somtime... unless your renting a movie.
# Output: just call me sometime sure any
# WER =  87.5
# ~~~
# The Ring (2002) Richard Morgan 233.wav
# Actual: My wife was not supposed to have a child!
# Output: I suppose
# WER =  100.0
# ~~~
# The Ring (2002) Aidan 234.wav
# Actual: Don't you understand Rachel? She never sleeps...
# Output:
# WER =  100.0
# ~~~
# The Ring (2002) Noah 235.wav
# Actual: I'm sure its a lot.... scarier at night.
# Output: I'm sure it's a lot
# WER =  50.0
# ~~~
# Pirates of the Caribbean - The Curse of the Black Pearl (2003) Captain Jack Sparrow 236.wav
# Actual: And then they made me their chief...
# Output:
# WER =  100.0
# ~~~
# Pirates of the Caribbean - The Curse of the Black Pearl (2003) Pirate 237.wav
# Actual: Hello chum!
# Output: shop
# WER =  100.0
# ~~~
# Pirates of the Caribbean - The Curse of the Black Pearl (2003) Captain Jack Sparrow 238.wav
# Actual: Stop blowing holes in my ship!
# Output:
# WER =  100.0
# ~~~
# Pirates of the Caribbean - The Curse of the Black Pearl (2003) Pirate 239.wav
# Actual: Now thats what you call ironic...
# Output:
# WER =  100.0
# ~~~
# Pirates of the Caribbean - The Curse of the Black Pearl (2003) Sparrow 240.wav
# Actual: There'll be no living with her after this...
# Output: I mean I live in with all
# WER =  100.0
# ~~~
# Pirates of the Caribbean - The Curse of the Black Pearl (2003) Captain Barbossa 241.wav
# Actual: I'm disinclined to acquiesce to your request. Means no.
# Output: no
# WER =  88.8888888889
# ~~~
# Pirates of the Caribbean - The Curse of the Black Pearl (2003) Captain Jack Sparrow 242.wav
# Actual: No! Not good! Stop! Not good!
# Output:
# WER =  100.0
# ~~~
# Pirates of the Caribbean - The Curse of the Black Pearl (2003) Pintel 243.wav
# Actual: Hello poppet.
# Output:
# WER =  100.0
# ~~~
# Pirates of the Caribbean - The Curse of the Black Pearl (2003) Captain Jack Sparrow 244.wav
# Actual: Welcome to the Caribbean love.
# Output: welcome to the carribean
# WER =  40.0
# ~~~
# Ladyhawke (1985) Mouse 245.wav
# Actual: It's not unlike escaping mother's womb... God what a memory!
# Output: escaping mother's womb the memory
# WER =  60.0
# ~~~
# Ladyhawke (1985) Mouse 246.wav
# Actual: You won't regret this Lord! I'm a wonderful person!
# Output: no one
# WER =  100.0
# ~~~
# The Road Warrior (Mad Max 2) (1981) Gyro Captain 247.wav
# Actual: Blew it you fool!
# Output:
# WER =  100.0
# ~~~
# The Road Warrior (Mad Max 2) (1981) Gyro Captain 248.wav
# Actual: Reflexes! That's what you got! Me, I got brains!
# Output: right one I Brian
# WER =  88.8888888889
# ~~~
# The Road Warrior (Mad Max 2) (1981) Mad Max 249.wav
# Actual: I'm the best chance you got.
# Output:
# WER =  100.0
# ~~~
# Shrek 2 (2004) Donkey 250.wav
# Actual: Look at our little mutant babies!
# Output:
# WER =  100.0
# ~~~
# Shrek 2 (2004) Shrek 251.wav
# Actual: It says beauty divine. How bad can it be?
# Output: it's a beauty divine how bad can it be
# WER =  22.2222222222
# ~~~
# Shrek 2 (2004) Fairy Godmother 252.wav
# Actual: My diet is ruined! I hope your happy!
# Output: I had to throw in that I hope you are happy
# WER =  100.0
# ~~~
# Shrek 2 (2004) Donkey 253.wav
# Actual: Shrek I think you grabbed the farty ever after potion!
# Output: you got to be sick I think you grab a how do you have after potion
# WER =  110.0
# ~~~
# Shrek 2 (2004) Puss in Boots 254.wav
# Actual: Ah HA! Fear me! If you dare!
# Output: dear me
# WER =  85.7142857143
# ~~~
# Shrek 2 (2004) Puss in Boots 255.wav
# Actual: Isn't we supposed to be having a fiesta!!
# Output: it was supposed to be hot enough
# WER =  62.5
# ~~~
# Shrek 2 (2004) Fairy Godmother 256.wav
# Actual: I told you Ogres don't live happily ever after!
# Output: hello it is funny some
# WER =  100.0
# ~~~
# Shrek 2 (2004) Shrek 257.wav
# Actual: It's so good to be home...
# Output: so good to be home
# WER =  16.6666666667
# ~~~
# Shrek 2 (2004) Fiona 258.wav
# Actual: Mom... Dad... I'd like you to meet my husband, Shrek.
# Output: mom dad I'd like you to meet my husband Shrek
# WER =  0.0
# ~~~
# Shrek 2 (2004) Donkey 259.wav
# Actual: I got to get a job.
# Output: I got to give Joe
# WER =  50.0
# ~~~
# Shrek 2 (2004) Shrek 260.wav
# Actual: I'll kill that cat!!
# Output: %HESITATION to
# WER =  100.0
# ~~~
# Shrek 2 (2004) Fairy Godmother 261.wav
# Actual: Ogre's don't live happily ever after.
# Output: okay them to live happily ever off
# WER =  66.6666666667
# ~~~
# Shrek 2 (2004) Fiona 262.wav
# Actual: He's completely lost his mind!
# Output: he's completely lost his mind
# WER =  0.0
# ~~~
# Shrek 2 (2004) Puss in Boots 263.wav
# Actual: I hate mondays.
# Output:
# WER =  100.0
# ~~~
# Shrek 2 (2004) Shrek 264.wav
# Actual: Well... look out princess. Here comes the new me!
# Output: well look at the princess here comes the new me
# WER =  22.2222222222
# ~~~
# Shrek 2 (2004) Donkey 265.wav
# Actual: Why don't you guys go ahead, I'll park the car.
# Output: %HESITATION guys go ahead I'll pop become
# WER =  60.0
# ~~~
# Shrek 2 (2004) Shrek 266.wav
# Actual: Hold the phone!
# Output: hello foreign
# WER =  100.0
# ~~~
# Shrek 2 (2004) Puss in Boots 267.wav
# Actual: Hey boss... let's shave him.
# Output: eva save him
# WER =  80.0
# ~~~
# Shrek 2 (2004) Gingy 268.wav
# Actual: Bah whizzes on you guys!
# Output: what is on you guys
# WER =  40.0
# ~~~
# Shrek 2 (2004) Shrek 269.wav
# Actual: Back away from my wife!
# Output: my wife
# WER =  60.0
# ~~~
# Shrek 2 (2004) Shrek 270.wav
# Actual: Working hard or hardly working, eh mack?
# Output:
# WER =  100.0
# ~~~
# Mad Max Beyond Thunderdome (1985) Dr. Dealgood 271.wav
# Actual: Ladies and gentlemen, boys and girls... dyin' times here.
# Output: ladies and gentleman boys and girls die he
# WER =  44.4444444444
# ~~~
# Mad Max Beyond Thunderdome (1985) Auntie 272.wav
# Actual: Well, ain't we a pair raggedy man. Goodbye Soldier!
# Output: well yes
# WER =  88.8888888889
# ~~~
# Mad Max Beyond Thunderdome (1985) Auntie 273.wav
# Actual: Welcome to another edition of Thunderdome
# Output: we're not
# WER =  100.0
# ~~~
# American Political Sounds  Ted Kennedy 274.wav
# Actual: Hello? Hello? That's what we are debating here?
# Output: hello hello that's what we're debating here
# WER =  25.0
# ~~~
# Sliders (1995-2000) Professor Arturo 275.wav
# Actual: Gentlemen, check your flies.
# Output: by
# WER =  100.0
# ~~~
# Sliders (1995-2000) Professor Arturo 276.wav
# Actual: I'm English! We invented fishing!
# Output: I mean wish we invented fishing
# WER =  60.0
# ~~~
# Sliders (1995-2000) Quinn 277.wav
# Actual: We're not in Kansas anymore.
# Output:
# WER =  100.0
# ~~~
# Sliders (1995-2000) Professor Arturo 278.wav
# Actual: I don't believe it! At last a soft landing!
# Output:
# WER =  100.0
# ~~~
# The Prisoner (1967-1968) Number 2 279.wav
# Actual: Thank you... that will be all.
# Output: Q. or
# WER =  100.0
# ~~~
# The Prisoner (1967-1968) Number 2 280.wav
# Actual: You really are the limit Number 6!
# Output: you believe it number three
# WER =  71.4285714286
# ~~~
# The Prisoner (1967-1968) Admiral 281.wav
# Actual: We're all pawns my dear.
# Output: we're old forms media
# WER =  80.0
# ~~~
# The Prisoner (1967-1968) Number 6 282.wav
# Actual: Be seeing you.
# Output:
# WER =  100.0
# ~~~
# Finding Nemo (2003) Mr. Ray 283.wav
# Actual: Huh... I wonder where my class has gone.
# Output: I wonder where my class had gone
# WER =  25.0
# ~~~
# Finding Nemo (2003) Dory 284.wav
# Actual: What is it with men and asking for directions?
# Output: is it with men and asking for two
# WER =  22.2222222222
# ~~~
# Finding Nemo (2003) Bruce 285.wav
# Actual: I'm having fish tonight!!
# Output:
# WER =  100.0
# ~~~
# Finding Nemo (2003) Bruce 286.wav
# Actual: Hello.
# Output:
# WER =  100.0
# ~~~
# Finding Nemo (2003) Pearl 287.wav
# Actual: Ahh you guys made me ink!
# Output:
# WER =  100.0
# ~~~
# Finding Nemo (2003) Bubbles 288.wav
# Actual: Bubbles!! Bubbles! My Bubbles!
# Output: my
# WER =  75.0
# ~~~
# Finding Nemo (2003) Mr Ray 289.wav
# Actual: Theeeeerrrrrrreeee's nothing to see. Gather uh, over there.
# Output: a %HESITATION is now over there
# WER =  75.0
# ~~~
# Finding Nemo (2003) Bloat 290.wav
# Actual: Now what?
# Output:
# WER =  100.0
# ~~~
# Finding Nemo (2003) Peach 291.wav
# Actual: That's the shortest red light I've ever seen!
# Output: red light I've ever seen
# WER =  37.5
# ~~~
# Finding Nemo (2003) Peach 292.wav
# Actual: Hey look, scum angel!
# Output: okay walk down a
# WER =  100.0
# ~~~
# Finding Nemo (2003) Sheldon 293.wav
# Actual: He touched the butt.
# Output:
# WER =  100.0
# ~~~
# Finding Nemo (2003) Marlin 294.wav
# Actual: Somethings wrong with you... really.
# Output: something's wrong with you really
# WER =  20.0
# ~~~
# Shark Tale (2004) Oscar 295.wav
# Actual: She's gonna blow!
# Output:
# WER =  100.0
# ~~~
# Shark Tale (2004) Lenny 296.wav
# Actual: Your a comic genius.
# Output: okay your comic genius
# WER =  50.0
# ~~~
# Shark Tale (2004) Shrimp 297.wav
# Actual: You're a good person.
# Output: troops could for sure
# WER =  100.0
# ~~~
# Shark Tale (2004) Lenny 298.wav
# Actual: Eye of the tiger.
# Output: I guess
# WER =  100.0
# ~~~
# Shark Tale (2004) Oscar 299.wav
# Actual: Unpleasant...
# Output:
# WER =  100.0
# ~~~
# Ella Enchanted (2004) Slannen 300.wav
# Actual: You are one freaky chick.
# Output: you are what freaky check
# WER =  40.0
# ~~~
# Ella Enchanted (2004) Thug 301.wav
# Actual: This chick is nuts!
# Output:
# WER =  100.0
# ~~~
# Ella Enchanted (2004) Slannen 302.wav
# Actual: I'm gonna need so much therapy after this!
# Output: I'm going to need
# WER =  87.5
# ~~~
# Ella Enchanted (2004) Ella 303.wav
# Actual: My tongue itches.
# Output: my tongue is
# WER =  33.3333333333
# ~~~
# Ella Enchanted (2004) Edgar 304.wav
# Actual: You vile little girl!
# Output: do
# WER =  100.0
# ~~~
# Firefly (2002) River 305.wav
# Actual: I can kill you with my brain.
# Output:
# WER =  100.0
# ~~~
# Firefly (2002) Kaylee 306.wav
# Actual: Don't let the space bugs bite!
# Output: don't let the bedbugs bite
# WER =  33.3333333333
# ~~~
# Firefly (2002) Jayne Cobb 307.wav
# Actual: I'll be in my bunk.
# Output:
# WER =  100.0
# ~~~
# Firefly (2002) Wash Washburne 308.wav
# Actual: Did he just go crazy and fall asleep?
# Output: did he just go crazy and fall asleep
# WER =  0.0
# ~~~
# Firefly (2002) River 309.wav
# Actual: It's getting very very crowded!
# Output: okay
# WER =  100.0
# ~~~
# Firefly (2002) River 310.wav
# Actual: You're not right Early. You're not righteous. You got issues.
# Output: not right early not righteous got issues
# WER =  30.0
# ~~~
# Firefly (2002) Jayne 311.wav
# Actual: Let's move this conversation in a not Jayne's fault direction.
# Output: all three
# WER =  100.0
# ~~~
# Firefly (2002) Simon 312.wav
# Actual: He's really very gentle and fuzzy. We're becoming fast friends.
# Output: it's really very gel and fuzzy we're becoming fast friends
# WER =  20.0
# ~~~
# Firefly (2002) Jubal Early 313.wav
# Actual: Well... here I am.
# Output: well zero
# WER =  75.0
# ~~~
# Firefly (2002) Jayne Cobb 314.wav
# Actual: Time for some thrilling heroics.
# Output:
# WER =  100.0
# ~~~
# Firefly (2002) Lieutenant Womack 315.wav
# Actual: That hat makes you look like an idiot.
# Output: I can
# WER =  100.0
# ~~~
# Firefly (2002) River Tam 316.wav
# Actual: No power in the Verse can stop me.
# Output: power and stop me
# WER =  62.5
# ~~~
# Firefly (2002) River 317.wav
# Actual: It's just an object. Doesn't mean what you think.
# Output: an object to me what you think
# WER =  44.4444444444
# ~~~
# Firefly (2002) Captain Malcolm Reynolds 318.wav
# Actual: You want to meet the 'real me' now!
# Output:
# WER =  100.0
# ~~~
# Firefly (2002) Kaylee Frye 319.wav
# Actual: No, it's shiny!
# Output: %HESITATION any
# WER =  100.0
# ~~~
# Firefly (2002) Wash Washburne 320.wav
# Actual: Here's something you can't do.
# Output:
# WER =  100.0
# ~~~
# Serenity (2005) Jayne Cobb 321.wav
# Actual: Shiny, let's be bad guys.
# Output: ninety speed bag
# WER =  100.0
# ~~~
# Serenity (2005) Shepherd Book 322.wav
# Actual: I don't care what you believe, just believe.
# Output: hear what you're busy
# WER =  87.5
# ~~~
# Serenity (2005) River 323.wav
# Actual: I swallowed a bug.
# Output:
# WER =  100.0
# ~~~
# Serenity (2005) Jayne Cobb 324.wav
# Actual: She is starting to damage my calm.
# Output: she is starting to damage my call
# WER =  14.2857142857
# ~~~
# Serenity (2005) Jayne Cobb 325.wav
# Actual: Eating people alive? Where does that get fun?
# Output: meeting people arrive
# WER =  87.5
# ~~~
# Serenity (2005) Operative 326.wav
# Actual: This is a good death... there's no shame in this.
# Output: same and
# WER =  100.0
# ~~~
# Serenity (2005) Wash 327.wav
# Actual: We all here? What's going on? Hello?
# Output: we are your one hello
# WER =  71.4285714286
# ~~~
# Serenity (2005) Operative 328.wav
# Actual: Where are you hiding little girl?
# Output:
# WER =  100.0
# ~~~
# Serenity (2005) Captain Malcolm Reynolds 329.wav
# Actual: I aim to misbehave.
# Output:
# WER =  100.0
# ~~~
# Serenity (2005) Operative 330.wav
# Actual: Target the Reavers. Target the Reavers! Target everyone! Somebody fire!!
# Output:
# WER =  100.0
# ~~~
# Serenity (2005) Captain Malcolm Reynolds 331.wav
# Actual: What was that?
# Output: what was that
# WER =  0.0
# ~~~
# Serenity (2005) Captain Malcolm Reynolds 332.wav
# Actual: Zoe? Are you here?
# Output: so we are you here
# WER =  50.0
# ~~~
# Lost (2004-2010) Hurley 333.wav
# Actual: Yeah... uh I'm not so good around blood.
# Output: yeah but good around let
# WER =  62.5
# ~~~
# Lost (2004-2010) Desmond 334.wav
# Actual: I'll see you in another life brother.
# Output:
# WER =  100.0
# ~~~
# Lost (2004-2010) Locke 335.wav
# Actual: Don't tell me what I can't do.
# Output:
# WER =  100.0
# ~~~
# Lost (2004-2010) Desmond 336.wav
# Actual: I think I crashed your plane.
# Output:
# WER =  100.0
# ~~~
# Lost (2004-2010) Voice 337.wav
# Actual: System Failure. System Failure.
# Output:
# WER =  100.0
# ~~~
# Lost (2004-2010) Shannon 338.wav
# Actual: My brother... Boone. God's friggen gift to humanity.
# Output: my brother %HESITATION god's forgiveness to humanity
# WER =  37.5
# ~~~
# Lost (2004-2010) Jack 339.wav
# Actual: You either have very good aim... or very bad aim.
# Output: very good aim or very bad aim
# WER =  30.0
# ~~~
# Lost (2004-2010) Kate 340.wav
# Actual: Put your gun back in your pants Sawyer.
# Output: to come back in your so I
# WER =  62.5
# ~~~
# Lost (2004-2010) Ben 341.wav
# Actual: Jack please! You don't know what you're doing!
# Output: please you don't know what you're doing
# WER =  12.5
# ~~~
# Lost (2004-2010) Hurley 342.wav
# Actual: Shut up redneck man!
# Output: sure read me man
# WER =  75.0
# ~~~
# Lost (2004-2010) Locke 343.wav
# Actual: Do you wanna know a secret?
# Output: do you want secret
# WER =  50.0
# ~~~
# Lost (2004-2010) Charlie 344.wav
# Actual: Terrific...
# Output: to
# WER =  100.0
# ~~~
# Lost (2004-2010) Charlie 345.wav
# Actual: Guys.... where are we?
# Output:
# WER =  100.0
# ~~~
# Lost (2004-2010) Locke 346.wav
# Actual: I was wrong!
# Output:
# WER =  100.0
# ~~~
# Charlie and the Chocolate Factory (2005) Willy Wonka 347.wav
# Actual: I'm closing my chocolate factory... forever. I'm sorry.
# Output: I'm losing my remember
# WER =  75.0
# ~~~
# Charlie and the Chocolate Factory (2005) Shopkeeper 348.wav
# Actual: You found Wonka's last golden ticket! In my shop too!
# Output: go sure
# WER =  100.0
# ~~~
# Charlie and the Chocolate Factory (2005) Willy Wonka 349.wav
# Actual: Good morning starshine! The earth says hello!
# Output: good morning star shine the earth says hello
# WER =  28.5714285714
# ~~~

# %%
def wer(r, h):

    # prepare strings
    r = r.lower()
    h = h.lower()
    
    exclude = set(['.', '!', '?', ','])
    r = ''.join(ch for ch in r if ch not in exclude)
    h = ''.join(ch for ch in h if ch not in exclude)
    
    r = r.split()
    h = h.split()
    
    # initialisation
    import numpy
    d = numpy.zeros((len(r)+1)*(len(h)+1), dtype=numpy.uint8)
    d = d.reshape((len(r)+1, len(h)+1))
    for i in range(len(r)+1):
        for j in range(len(h)+1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i

    # computation
    for i in range(1, len(r)+1):
        for j in range(1, len(h)+1):
            if r[i-1] == h[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                substitution = d[i-1][j-1] + 1
                insertion    = d[i][j-1] + 1
                deletion     = d[i-1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)

    return d[len(r)][len(h)]
